# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langgraph.graph import END, START, StateGraph, MessagesState
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langgraph.prebuilt import ToolNode
from typing import Literal

# %%
@tool
def get_weather(location: str):
    """Call to get the current weather."""
    if location.lower() in ["munich"]:
        return "It's 15 degrees Celsius and cloudy."
    else:
        return "It's 32 degrees Celsius and sunny."

# %%
get_weather.invoke(input={"location": "munich"})
# Out:
# "It's 15 degrees Celsius and cloudy."

# %%
tools = [get_weather]
model = ChatOpenAI(model="gpt-4o-mini").bind_tools(tools)

# %%
model.invoke("hello")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 45, 'total_tokens': 55, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6BMeviXnzxPqhVHaQP14fKvnvci', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--bdc723ad-0faf-44f3-bcd0-be0f6013fec6-0', usage_metadata={'input_tokens': 45, 'output_tokens': 10, 'total_tokens': 55, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model.invoke("How is the weather in munich?")
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6BP2jYCN9Pvudse3yS2JSvGQTx0', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6174b856-b33a-4691-87b4-0685923868f8-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Munich'}, 'id': 'call_323vxOjvkRSqci8WYoqnbMwQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
def call_model(state: MessagesState):
    messages = state["messages"]
    response = model.invoke(messages)
    return {"messages": [response]}


def should_continue(state: MessagesState) -> Literal["tools", END]:
    messages = state["messages"]
    last_message = messages[-1]
    if last_message.tool_calls:
        return "tools"
    return END

# %%
workflow = StateGraph(MessagesState)
tool_node = ToolNode(tools)

workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# %%
workflow.add_edge(START, "agent")

workflow.add_conditional_edges(
    "agent",
    should_continue,
)
workflow.add_edge("tools", "agent")

# %%
graph = workflow.compile()

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
from langchain_core.messages import HumanMessage

messages1 = [HumanMessage(content="Hello, how are you?")]
messages2 = [HumanMessage(content="How is the weather in munich?")]

# %%
graph.invoke({"messages": messages1})
# Out:
# {'messages': [HumanMessage(content='Hello, how are you?', additional_kwargs={}, response_metadata={}, id='e36b764e-1ea0-4070-8622-0b98f8eb78f6'),
#   AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to assist you. How can I help you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 50, 'total_tokens': 81, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6Bq02CImhblHsP7gQMUpS6NhOu0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--d87981b4-fc79-4074-8705-08c56823e1df-0', usage_metadata={'input_tokens': 50, 'output_tokens': 31, 'total_tokens': 81, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
graph.invoke({"messages": messages2})
# Out:
# {'messages': [HumanMessage(content='How is the weather in munich?', additional_kwargs={}, response_metadata={}, id='00e306a7-3a12-470e-b665-b13c6ff71d92'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6Bua6dYQo9piPMApVirht8k5G7c', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--84488bbd-2dce-4c9a-88e4-ef7f7c6fabac-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'munich'}, 'id': 'call_GxCPLwYpndfo28yPEHa6mgza', 'type': 'tool_call'}], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="It's 15 degrees Celsius and cloudy.", name='get_weather', id='5d840c6a-326d-4e2f-b78e-f3ef5bf7fc49', tool_call_id='call_GxCPLwYpndfo28yPEHa6mgza'),
#   AIMessage(content='The weather in Munich is currently 15 degrees Celsius and cloudy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 83, 'total_tokens': 97, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6Buyvy5WI2B9p9R2Ju4My0I6Mcw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--9c8bf2c7-9699-4ca7-a54b-6e9137d43a34-0', usage_metadata={'input_tokens': 83, 'output_tokens': 14, 'total_tokens': 97, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
graph.invoke(
    {
        "messages": [
            HumanMessage(content="What would you recommend to do in that city than?")
        ]
    }
)
# Out:
# {'messages': [HumanMessage(content='What would you recommend to do in that city than?', additional_kwargs={}, response_metadata={}, id='aa3183ab-fa3c-483b-99a6-da97d1111a00'),
#   AIMessage(content="I can provide recommendations if you tell me which city you're interested in!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 55, 'total_tokens': 70, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6DgrsfqvSGFKzqrrTACLWHnEEGT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--72c42ae1-328e-4c43-b18d-de63cb3b3b3d-0', usage_metadata={'input_tokens': 55, 'output_tokens': 15, 'total_tokens': 70, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ### Add Memory to chatbot

# %%
from langgraph.checkpoint.memory import MemorySaver

checkpointer = MemorySaver()

# %%
workflow = StateGraph(MessagesState)

workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")

workflow.add_conditional_edges(
    "agent",
    should_continue,
)
workflow.add_edge("tools", "agent")

graph = workflow.compile(checkpointer=checkpointer)

# %%
graph.invoke(
    {"messages": [HumanMessage(content="How is the weather in munich?")]},
    config={"configurable": {"thread_id": 1}},
)
# Out:
# {'messages': [HumanMessage(content='How is the weather in munich?', additional_kwargs={}, response_metadata={}, id='6e80f26f-5f8c-4aa5-bb9c-3a03fe3736d8'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6F0CsqbAQ57drAvYQnqcraaLdSL', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--2fac52f5-9782-46db-9ca8-b959aba09b15-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'munich'}, 'id': 'call_eRnIOOw8LLc03DMfzFPuQP7S', 'type': 'tool_call'}], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="It's 15 degrees Celsius and cloudy.", name='get_weather', id='edb0926d-cce3-42e9-847a-6ee4f1dc25cf', tool_call_id='call_eRnIOOw8LLc03DMfzFPuQP7S'),
#   AIMessage(content='The weather in Munich is currently 15 degrees Celsius and cloudy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 83, 'total_tokens': 97, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6F1jFrEulT9DWv653hLf4ALC6xV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--8b7b76f6-c0ca-437d-8f88-e5c42164777f-0', usage_metadata={'input_tokens': 83, 'output_tokens': 14, 'total_tokens': 97, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
graph.invoke(
    {
        "messages": [
            HumanMessage(content="What would you recommend to do in that city than?")
        ]
    },
    config={"configurable": {"thread_id": 1}},
)
# Out:
# {'messages': [HumanMessage(content='How is the weather in munich?', additional_kwargs={}, response_metadata={}, id='6e80f26f-5f8c-4aa5-bb9c-3a03fe3736d8'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6F0CsqbAQ57drAvYQnqcraaLdSL', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--2fac52f5-9782-46db-9ca8-b959aba09b15-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'munich'}, 'id': 'call_eRnIOOw8LLc03DMfzFPuQP7S', 'type': 'tool_call'}], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="It's 15 degrees Celsius and cloudy.", name='get_weather', id='edb0926d-cce3-42e9-847a-6ee4f1dc25cf', tool_call_id='call_eRnIOOw8LLc03DMfzFPuQP7S'),
#   AIMessage(content='The weather in Munich is currently 15 degrees Celsius and cloudy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 83, 'total_tokens': 97, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6F1jFrEulT9DWv653hLf4ALC6xV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--8b7b76f6-c0ca-437d-8f88-e5c42164777f-0', usage_metadata={'input_tokens': 83, 'output_tokens': 14, 'total_tokens': 97, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='What would you recommend to do in that city than?', additional_kwargs={}, response_metadata={}, id='cf274e8d-6fef-4c42-bebb-090a4d77f3e5'),
#   AIMessage(content="In Munich, with its cool and cloudy weather, here are some recommendations for activities you can enjoy:\n\n1. **Visit Museums**: Check out the Deutsches Museum, which is one of the world's largest museums dedicated to science and technology. The Pinakothek art museums are also great options for art lovers.\n\n2. **Explore Marienplatz**: This central square is home to the iconic New Town Hall (Neues Rathaus) and offers a vibrant atmosphere with shops and restaurants.\n\n3. **Bavarian Cuisine**: Enjoy traditional Bavarian food at local beer gardens or restaurants. Don't miss out on pretzels, sausages, and local beers.\n\n4. **Stroll in the Englischer Garten**: Take a leisurely walk in this vast park, which is perfect for a cloudy day. You can also find beer gardens within the park.\n\n5. **Nymphenburg Palace**: Visit this stunning Baroque palace with beautiful gardens. It’s a wonderful place to explore the architecture and history.\n\n6. **Attend a Local Event**: Check if there are any local events, fairs, or concerts happening during your visit.\n\n7. **Shopping**: Explore the shops along Maximilianstraße and Kaufingerstraße for both luxury and local boutiques.\n\n8. **Café Culture**: Cozy up in one of Munich's many cafes with a warm beverage and a slice of cake.\n\nWith the weather being cloudy, indoor activities like visiting museums and enjoying traditional cuisine would be particularly enjoyable!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 302, 'prompt_tokens': 115, 'total_tokens': 417, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ecd441ec78', 'id': 'chatcmpl-Dz6FRoMYgiojNnPqq8GMDAkMqyJVJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--fe5ffe2e-d8a7-4e61-bdbe-52a600b62539-0', usage_metadata={'input_tokens': 115, 'output_tokens': 302, 'total_tokens': 417, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
